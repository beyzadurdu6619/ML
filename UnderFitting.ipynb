# %% [markdown]
# <a href="https://colab.research.google.com/github/beyzadurdu6619/ML/blob/main/UnderFitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#UnderFitting -Az ÖĞRENME
#OverFitting -Aşırı ÖĞRENME
#BalangeFitting -Dengeli ÖĞRENME

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=sns.load_dataset("diamonds")

# %%
df.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
df=pd.get_dummies(df,columns=["cut","color","clarity"],drop_first=True)

# %%
df.head(3)
# Out:
#    carat  depth  table  price     x     y     z  cut_Premium  cut_Very Good  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43        False          False
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31         True          False
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31        False          False
#
#    cut_Good  ...  color_H  color_I  color_J  clarity_VVS1  clarity_VVS2  \
# 0     False  ...    False    False    False         False         False
# 1     False  ...    False    False    False         False         False
# 2      True  ...    False    False    False         False         False
#
#    clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  clarity_I1
# 0        False        False        False         True       False
# 1        False        False         True        False       False
# 2         True        False        False        False       False
#
# [3 rows x 24 columns]

# %%
y=df["price"]
x=df.drop("price",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
l=LinearRegression()
model=l.fit(x_train,y_train)

# %%
model.score(x_test,y_test)
# Out:
# 0.9189331350419387

# %%
model.score(x_train,y_train)
# Out:
# 0.919994314909212

# %%
#veri önişleme ve büyük veri seti verimlidir.
#train ve test scoreları arasındaki fark ne kadar azsa o kadatutarlıdır.
