# %% [markdown]
# <a href="https://colab.research.google.com/github/beyzadurdu6619/ML/blob/main/DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from sklearn.model_selection import train_test_split
import graphviz

# %%
df=pd.read_csv('heart.csv')

# %%
df.head(3)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1

# %%
y=df['output']
x=df.drop('output',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.09,random_state=19)

# %%
tree=DecisionTreeClassifier()
model=tree.fit(x_train,y_train) #öğrenme

# %%
model.score(x_test,y_test)
# Out:
# 0.75

# %%
x.head(1)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
#
#    caa  thall
# 0    0      1

# %%
tahmin=model.predict([[25,0,1,230,1,0,100,0,2,0,0,0,1]])
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
if tahmin==1:
  print("kalma ihtimali vardır")
else:
  print("kalma ihtimali yoktur")
# Out:
# kalma ihtimali yoktur

# %%
dot=export_graphviz(model,feature_names=x.columns)
gorsel=graphviz.Source(dot)
gorsel
