# %% [markdown]
# <a href="https://colab.research.google.com/github/beyzadurdu6619/ML/blob/main/RidgeRegresyon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ridge Regresyon aşırı öğrenme durumları için kullanılır.
#Ridge Regresyon sayesinde Bias ve varyans arasındaki dengeyi sağlarız.
#Ridge Regresyonda katsayılar üzerinde regülasyon yapılır.
#Ridge Regresyonda katsayılar 0 olmaz.
#Ridge Regresyonda cezalar karesi ile orantılı
#Ridge Regresyon L2

# %%
#y=a1*x1+a2*x2+.....+b+alfa*(katsayılar toplamı)**2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("student.csv")

# %%
df.head(3)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811

# %%
y=df["Marks"]
x=df[["time_study"]]

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(8,8))
plt.scatter(x,y,color="red")
plt.show()

# %%
l=LinearRegression()
model=l.fit(x,y)

# %%
model.score(x,y)
# Out:
# 0.8878423939061949

# %%
alfalar=[1,10,20,100,200]
for i in alfalar:
    from sklearn.linear_model import Ridge
    r=Ridge(alpha=i)
    model_ridge=r.fit(x,y)
    skor=model_ridge.score(x,y)
    print("Skor:",skor)
    print("Katsayı:",model.coef_)
# Out:
# Skor: 0.8878395469511184
# Katsayı: [5.68875042]
# Skor: 0.8875666577020126
# Katsayı: [5.68875042]
# Skor: 0.886777319407795
# Katsayı: [5.68875042]
# Skor: 0.8673013865239424
# Katsayı: [5.68875042]
# Skor: 0.8259413810656739
# Katsayı: [5.68875042]

# %%
#Burda aşırı öğrenmeye karşı güncelledik
